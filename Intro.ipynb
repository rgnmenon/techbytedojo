# %%
print("Hello Adam1")
print("Yaay! We have the first code segment run!")
# Out:
# Hello Adam1
# Yaay! We have the first code segment run!

# %%
print("Hello")
# Out:
# Hello

# %%
print('Hello, Eve is my name')
# Out:
# Hello, Eve is my name

# %%
print( 1 + 1 )
# Out:
# 2

# %%
# I did this because ... qeqwe
print("Hi")
# Out:
# Hi
