# %%
#programmer should think sensiblity and anticipate

noval = None
print(noval)
if(noval is None):
    print("noval variable now has:"+str(noval))
else:
    print("Not None ")

noval = "None"
print(noval)
if(noval is None):
    print("noval variable now has::"+str(noval))
else:
    print("Not None ")

noval = ""
print("noval variable now has:::"+noval)
# Out:
# None
# noval variable now has:None
# None
# Not None
# noval variable now has:::

# %%
inf = 5/0 # division by zero
print(inf)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-26-802625fd76c4> in <cell line: 1>()
# ----> 1 inf = 5/0 # division by zero
#       2 print(inf)
#
# ZeroDivisionError: division by zero

# %%
try:
  inf = 5/0 # division by zero
  print(inf)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
  inf = 5/0 # division by zero
  print(inf)
except Exception as e: #gereral - all
  print(e)
  print("An exception occurred "+ str(e))
# Out:
# division by zero
# An exception occurred division by zero

# %%
try:
  inf = 5/0 # division by zero
  print(inf)
except ZeroDivisionError as e:
  print(e)
  print("An exception occurred "+ str(e))
except Exception as ex:
  print("Something else")
# Out:
# division by zero
# An exception occurred division by zero
