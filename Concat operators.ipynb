# %%
hw = "Hell0 " + "World"
print( hw )
# Out:
# Hell0 World

# %%
v1 = 5 + 6
print(v1)
print('v1')
# Out:
# 11
# v1

# %%
v2 = 10
print(v2)
v3 = v2 + v1

print(v3)
print (5 + v1 )
# Out:
# 10
# 21
# 16

# %%
print ("The value for v1 is " + str(v1) )
# Out:
# The value for v1 is 11
