# %%
#Important will be used later

a = 33
b = 33
if a == b:
  print("a is equal to b")
  print("Done and Done")
print("Done finally!")
# Out:
# a is equal to b
# Done and Done
# Done finally!

# %%
a = 35
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else: # none of the above condtions were met
  print("a is greater than b")
# Out:
# a is greater than b
